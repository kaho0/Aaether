# %% [markdown]
# <a href="https://colab.research.google.com/github/kaho0/Abstract/blob/main/MidTerm_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python for ML Mid Term**

# %% [markdown]
# # **1) NumPy**

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

ids = np.arange(1, 11)
ages = np.random.randint(18, 60, 10)
salaries = np.random.randint(30000, 90000, 10)
departments = np.array(["HR", "IT", "Finance", "IT", "HR", "Sales", "Finance", "IT", "Sales", "HR"])

DF = pd.DataFrame({
"id": ids,
"age": ages,
"salary": salaries,
"dept": departments
})

DF.to_csv("employees.csv", index=False)
print("Sample Data Created and Saved as employees.csv")
DF
# Out:
# Sample Data Created and Saved as employees.csv
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# 5   6   56   30769    Sales
# 6   7   36   89735  Finance
# 7   8   40   86101       IT
# 8   9   28   32433    Sales
# 9  10   28   35311       HR

# %% [markdown]
# ![Screenshot 2025-10-23 223637.png](data:image/png;base64,...)

# %%
print("For ages: ")
age_arr=np.array(DF['age'])
print(age_arr)
print(age_arr.shape)
print(age_arr.ndim)
print(age_arr.shape)
print(age_arr.size)
print("For salaries: ")
sal_arr=np.array(DF['salary'])
print(sal_arr)
print(sal_arr.shape)
print(sal_arr.ndim)
print(sal_arr.shape)
print(sal_arr.size)
# Out:
# For ages:
# [56 46 32 25 38 56 36 40 28 28]
# (10,)
# 1
# (10,)
# 10
# For salaries:
# [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# (10,)
# 1
# (10,)
# 10

# %% [markdown]
# ![Screenshot 2025-10-23 223745.png](data:image/png;base64,...)

# %%
max_sal=np.max(sal_arr)
print(max_sal)
min_sal=np.min(sal_arr)
print(min_sal)
mean_sal=np.mean(sal_arr)
print(mean_sal)
# Out:
# 89735
# 30769
# 57446.9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
over_30=age_arr[age_arr>30]
print(over_30)
count_over_30 = np.sum(age_arr > 30)
print(count_over_30)
# Out:
# [56 46 32 38 56 36 40]
# 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
new_age=age_arr+5
print(new_age)
# Out:
# [61 51 37 30 43 61 41 45 33 33]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
total_sal=np.sum(sal_arr)
print(total_sal)
diff_between_max_min=max_sal-min_sal
print(diff_between_max_min)
# Out:
# 574469
# 58966

# %% [markdown]
# # **2) Pandas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/employees.csv')
print(df.head(5))
df.info()
df.describe()
# Out:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   age     10 non-null     int64
#  2   salary  10 non-null     int64
#  3   dept    10 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 452.0+ bytes
#              id       age        salary
# count  10.00000  10.00000     10.000000
# mean    5.50000  38.50000  57446.900000
# std     3.02765  11.16791  24357.262884
# min     1.00000  25.00000  30769.000000
# 25%     3.25000  29.00000  33152.500000
# 50%     5.50000  37.00000  58556.500000
# 75%     7.75000  44.50000  76426.000000
# max    10.00000  56.00000  89735.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
first_3_col=df[['id','age','salary']]
first_3_col
# Out:
#    id  age  salary
# 0   1   56   77191
# 1   2   46   74131
# 2   3   32   46023
# 3   4   25   71090
# 4   5   38   31685
# 5   6   56   30769
# 6   7   36   89735
# 7   8   40   86101
# 8   9   28   32433
# 9  10   28   35311

# %%
first_3_col.tail(3)
# Out:
#    id  age  salary
# 7   8   40   86101
# 8   9   28   32433
# 9  10   28   35311

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
people_in_IT=df[(df['dept']=='IT')]
print(people_in_IT)
print("total people in IT: ")
print(len(people_in_IT))
# Out:
#    id  age  salary dept
# 1   2   46   74131   IT
# 3   4   25   71090   IT
# 7   8   40   86101   IT
# total people in IT:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
top_paid=df.sort_values('salary',ascending=False).head(3)
print(top_paid[['salary','dept','age']])
# Out:
#    salary     dept  age
# 6   89735  Finance   36
# 7   86101       IT   40
# 0   77191       HR   56

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.loc[df['salary']>80000,'salary']=80000
df
# Out:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# 5   6   56   30769    Sales
# 6   7   36   80000  Finance
# 7   8   40   80000       IT
# 8   9   28   32433    Sales
# 9  10   28   35311       HR

# %%
average_salary = df['salary'].mean()
print("Average salary: ",average_salary)
# Out:
# Average salary:  55863.3
